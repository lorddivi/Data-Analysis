# %%
import pandas as pd

# %%
hero = pd.read_pickle('hero_info.pkl')

# %%
hero.head(5)
# Out:
#                 name   sex eye color     race hair color  height  publisher  \
# 0           Abin Sur  Male      blue  Ungaran    No Hair     185  DC Comics
# 1       Adam Strange  Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott  Male      blue        -      Blond     180  DC Comics
# 3  Alfred Pennyworth  Male      blue    Human      Black     178  DC Comics
# 4              Amazo  Male       red  Android          -     257  DC Comics
#
#   alignment  weight
# 0      good    90.0
# 1      good    88.0
# 2      good    90.0
# 3      good    72.0
# 4       bad   173.0

# %%
hero.loc[2,'race'] =  'unknown' # or .iloc[2,3]

# %%
hero.head(5)
# Out:
#                 name   sex eye color     race hair color  height  publisher  \
# 0           Abin Sur  Male      blue  Ungaran    No Hair     185  DC Comics
# 1       Adam Strange  Male      blue    Human      Blond     185  DC Comics
# 2         Alan Scott  Male      blue  unknown      Blond     180  DC Comics
# 3  Alfred Pennyworth  Male      blue    Human      Black     178  DC Comics
# 4              Amazo  Male       red  Android          -     257  DC Comics
#
#   alignment  weight
# 0      good    90.0
# 1      good    88.0
# 2      good    90.0
# 3      good    72.0
# 4       bad   173.0

# %%
hero.loc[hero['race']=='-','race'] = 'unknown'

# %%
hero[hero['race']=='unknown']
# Out:
#                name     sex eye color     race hair color  height  \
# 2        Alan Scott    Male      blue  unknown      Blond     180
# 7          Aquababy    Male      blue  unknown      Blond     -99
# 12             Atom    Male      blue  unknown        Red     178
# 13             Atom    Male         -  unknown          -     -99
# 14        Atom Girl  Female     black  unknown      Black     168
# ..              ...     ...       ...      ...        ...     ...
# 594      Wonder Man    Male       red  unknown      Black     188
# 595          Wondra  Female         -  unknown          -     -99
# 596  Wyatt Wingfoot    Male     brown  unknown      Black     196
# 598           X-Man    Male      blue  unknown      Brown     175
# 599     Yellow Claw    Male      blue  unknown    No Hair     188
#
#          publisher alignment  weight
# 2        DC Comics      good    90.0
# 7        DC Comics      good     NaN
# 12       DC Comics      good    68.0
# ...

# %%
hero.loc[533]
# Out:
# name             Spider-Man
# sex                    Male
# eye color             brown
# race                  Human
# hair color            Black
# height                  157
# publisher     Marvel Comics
# alignment              good
# weight                 56.0
# Name: 533, dtype: object

# %%
hero.loc[1000] = hero.loc[533]

# %%
hero.loc[1000]
# Out:
# name             Spider-Man
# sex                    Male
# eye color             brown
# race                  Human
# hair color            Black
# height                  157
# publisher     Marvel Comics
# alignment              good
# weight                 56.0
# Name: 1000, dtype: object

# %%
#iloc can only be used for existing row

# %%
hero['height']
# Out:
# 0       185
# 1       185
# 2       180
# 3       178
# 4       257
#        ...
# 599     188
# 600     183
# 601     165
# 602     305
# 1000    157
# Name: height, Length: 604, dtype: int64

# %%
hero['height']*0.0328084 #hero height in ft
# Out:
# 0        6.069554
# 1        6.069554
# 2        5.905512
# 3        5.839895
# 4        8.431759
#           ...
# 599      6.167979
# 600      6.003937
# 601      5.413386
# 602     10.006562
# 1000     5.150919
# Name: height, Length: 604, dtype: float64

# %%
hero['height']=hero['height']*0.0328084

# %%
numeric_cols = hero.select_dtypes(include = 'number').columns

# %%
numeric_cols
# Out:
# Index(['height', 'weight'], dtype='object')

# %%
hero[numeric_cols]
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      5.839895    72.0
# 4      8.431759   173.0
# ...         ...     ...
# 599    6.167979    95.0
# 600    6.003937    83.0
# 601    5.413386    52.0
# 602   10.006562   -99.0
# 1000   5.150919    56.0
#
# [604 rows x 2 columns]

# %%
hero[numeric_cols]=hero[numeric_cols]*100

# %%
hero[numeric_cols]
# Out:
#           height   weight
# 0      606.95540   9000.0
# 1      606.95540   8800.0
# 2      590.55120   9000.0
# 3      583.98952   7200.0
# 4      843.17588  17300.0
# ...          ...      ...
# 599    616.79792   9500.0
# 600    600.39372   8300.0
# 601    541.33860   5200.0
# 602   1000.65620  -9900.0
# 1000   515.09188   5600.0
#
# [604 rows x 2 columns]

# %%
hero[numeric_cols] = hero[numeric_cols]/100

# %%
hero[numeric_cols]
# Out:
#          height  weight
# 0      6.069554    90.0
# 1      6.069554    88.0
# 2      5.905512    90.0
# 3      5.839895    72.0
# 4      8.431759   173.0
# ...         ...     ...
# 599    6.167979    95.0
# 600    6.003937    83.0
# 601    5.413386    52.0
# 602   10.006562   -99.0
# 1000   5.150919    56.0
#
# [604 rows x 2 columns]

# %%
#adding new column

# %%
hero['bmi'] =hero['weight']/(hero['height']/3.28)**2

# %%
hero.columns
# Out:
# Index(['name', 'sex', 'eye color', 'race', 'hair color', 'height', 'publisher',
#        'alignment', 'weight', 'bmi'],
#       dtype='object')

# %%
hero.head(2)
# Out:
#            name   sex eye color     race hair color    height  publisher  \
# 0      Abin Sur  Male      blue  Ungaran    No Hair  6.069554  DC Comics
# 1  Adam Strange  Male      blue    Human      Blond  6.069554  DC Comics
#
#   alignment  weight        bmi
# 0      good    90.0  26.283103
# 1      good    88.0  25.699034

# %%
hero_ref = hero #shallow copy 
hero_copy = hero.copy() # real deep copy doesn't impact original

# %%
hero_ref.columns
# Out:
# Index(['name', 'sex', 'eye color', 'race', 'hair color', 'height', 'publisher',
#        'alignment', 'weight', 'bmi'],
#       dtype='object')

# %%
hero_copy['copy'] = True

# %%
hero_copy is hero
# Out:
# False

# %%
#Sorting the data

# %%
hero.head(5)
# Out:
#                 name   sex eye color     race hair color    height  publisher  \
# 0           Abin Sur  Male      blue  Ungaran    No Hair  6.069554  DC Comics
# 1       Adam Strange  Male      blue    Human      Blond  6.069554  DC Comics
# 2         Alan Scott  Male      blue  unknown      Blond  5.905512  DC Comics
# 3  Alfred Pennyworth  Male      blue    Human      Black  5.839895  DC Comics
# 4              Amazo  Male       red  Android          -  8.431759  DC Comics
#
#   alignment  weight        bmi
# 0      good    90.0  26.283103
# 1      good    88.0  25.699034
# 2      good    90.0  27.763556
# 3      good    72.0  22.712769
# 4       bad   173.0  26.179265

# %%
hero.sort_values(by = 'race')#A-Z
# Out:
#               name     sex eye color     race hair color    height  \
# 341       Evilhawk    Male       red    Alien      Black  6.266404
# 302        Century    Male     white    Alien      White  6.594488
# 268      Blackwulf    Male       red    Alien      White  6.167979
# 520  Silver Surfer    Male     white    Alien    No Hair  6.332021
# 236         Ardina  Female     white    Alien     Orange  6.332021
# ..             ...     ...       ...      ...        ...       ...
# 249  Beta Ray Bill    Male         -  unknown    No Hair  6.594488
# 248         Beetle    Male         -  unknown          - -3.248032
# 246           Beak    Male     black  unknown      White  5.741470
# 244         Bantam    Male     brown  unknown      Black  5.413386
# 301  Cecilia Reyes       -     brown  unknown      Brown  5.577428
#
#          publisher alignment  weight         bmi
# 341  Marvel Comics       bad   106.0   29.041344
# 302  Marvel Comics      good    97.0   23.997014
# ...

# %%
hero.sort_values(by = 'race',ascending = False)#Z-A
# Out:
#               name     sex eye color     race hair color    height  \
# 403  Jennifer Kale  Female      blue  unknown      Blond  5.511811
# 510    Shadow King       -       red  unknown          -  6.069554
# 307          Cloak    Male     brown  unknown      black  7.414698
# 306           Clea       -         -  unknown      White -3.248032
# 305     Changeling    Male     brown  unknown      Black  5.905512
# ..             ...     ...       ...      ...        ...       ...
# 103         Indigo  Female         -    Alien     Purple -3.248032
# 268      Blackwulf    Male       red    Alien      White  6.167979
# 341       Evilhawk    Male       red    Alien      Black  6.266404
# 70        Doomsday    Male       red    Alien      White  8.005250
# 302        Century    Male     white    Alien      White  6.594488
#
#          publisher alignment  weight         bmi
# 403  Marvel Comics      good    55.0   19.476984
# 510  Marvel Comics      good   149.0   43.513137
# ...

# %%
hero.sort_values(by = 'bmi',ascending = False).head()
# Out:
#             name     sex eye color               race hair color    height  \
# 566  Utgard-Loki    Male      blue        Frost Giant      White  0.492126
# 86       Giganta  Female     green            unknown        Red  2.066929
# 492     Red Hulk    Male    yellow  Human / Radiation      Black  6.988189
# 64      Darkseid    Male       red            New God    No Hair  8.759843
# 431  Machine Man       -       red            unknown      Black  6.003937
#
#          publisher alignment  weight          bmi
# 566  Marvel Comics       bad    58.0  2576.457960
# 86       DC Comics       bad   630.0  1586.488891
# 492  Marvel Comics   neutral   630.0   138.790240
# 64       DC Comics       bad   817.0   114.545259
# 431  Marvel Comics      good   383.0   114.307356

# %%
hero[['race','height']].sort_values(by = ['race','height'])
# Out:
#         race     height
# 103    Alien  -3.248032
# 268    Alien   6.167979
# 341    Alien   6.266404
# 236    Alien   6.332021
# 520    Alien   6.332021
# ..       ...        ...
# 434  unknown   6.988189
# 556  unknown   7.152231
# 307  unknown   7.414698
# 502  unknown  10.006562
# 592  unknown  12.007874
#
# [604 rows x 2 columns]

# %%
hero[['race','height']].sort_values(by = ['height','race'],ascending = [True,False])
# Out:
#                 race     height
# 7            unknown  -3.248032
# 13           unknown  -3.248032
# 16           unknown  -3.248032
# 17           unknown  -3.248032
# 19           unknown  -3.248032
# ..               ...        ...
# 592          unknown  12.007874
# 449           Cyborg  12.007874
# 376   Flora Colossus  22.998688
# 357    Cosmic Entity  28.740158
# 347  Kakarantharaian  31.988190
#
# [604 rows x 2 columns]

# %%
hero.nlargest(n=10,columns = 'height')#more efficient
# Out:
#                name     sex eye color             race hair color     height  \
# 347   Fin Fang Foom    Male       red  Kakarantharaian    No Hair  31.988190
# 357        Galactus    Male     black    Cosmic Entity      Black  28.740158
# 376           Groot    Male    yellow   Flora Colossus          -  22.998688
# 449           MODOK    Male     white           Cyborg     Brownn  12.007874
# 592       Wolfsbane  Female     green          unknown     Auburn  12.007874
# 475       Onslaught    Male       red           Mutant    No Hair  10.006562
# 502       Sasquatch    Male       red          unknown     Orange  10.006562
# 602            Ymir    Male     white      Frost Giant    No Hair  10.006562
# 409      Juggernaut    Male      blue            Human        Red   9.416011
# 186  Solomon Grundy    Male     black           Zombie      White   9.153544
#
#          publisher alignment  weight         bmi
# 347  Marvel Comics      good    18.0    0.189252
# ...

# %%
hero.sort_values(by = 'height',ascending = False).head(10)
# Out:
#                name     sex eye color             race hair color     height  \
# 347   Fin Fang Foom    Male       red  Kakarantharaian    No Hair  31.988190
# 357        Galactus    Male     black    Cosmic Entity      Black  28.740158
# 376           Groot    Male    yellow   Flora Colossus          -  22.998688
# 449           MODOK    Male     white           Cyborg     Brownn  12.007874
# 592       Wolfsbane  Female     green          unknown     Auburn  12.007874
# 475       Onslaught    Male       red           Mutant    No Hair  10.006562
# 602            Ymir    Male     white      Frost Giant    No Hair  10.006562
# 502       Sasquatch    Male       red          unknown     Orange  10.006562
# 409      Juggernaut    Male      blue            Human        Red   9.416011
# 186  Solomon Grundy    Male     black           Zombie      White   9.153544
#
#          publisher alignment  weight         bmi
# 347  Marvel Comics      good    18.0    0.189252
# ...

# %%
hero.nsmallest(n= 10,columns = 'height')
# Out:
#            name     sex eye color     race hair color    height  publisher  \
# 7      Aquababy    Male      blue  unknown      Blond -3.248032  DC Comics
# 10      Arsenal    Male         -    Human          - -3.248032  DC Comics
# 13         Atom    Male         -  unknown          - -3.248032  DC Comics
# 16     Atom III    Male         -  unknown        Red -3.248032  DC Comics
# 17      Atom IV    Male     brown  unknown      Black -3.248032  DC Comics
# 18       Azrael    Male     brown    Human      Black -3.248032  DC Comics
# 19        Aztar    Male         -  unknown          - -3.248032  DC Comics
# 21      Batgirl  Female         -  unknown          - -3.248032  DC Comics
# 23  Batgirl III  Female         -  unknown          - -3.248032  DC Comics
# 25    Batgirl V  Female         -  unknown          - -3.248032  DC Comics
#
#    alignment  weight        bmi
# 7       good     NaN        NaN
# 10      good     NaN        NaN
# 13      good     NaN        NaN
# ...

# %%
hero[hero['height']>0].nsmallest(n= 10,columns = 'height')
# Out:
#                   name     sex eye color           race hair color    height  \
# 566        Utgard-Loki    Male      blue    Frost Giant      White  0.492126
# 279        Bloodwraith    Male     white        unknown    No Hair  1.017060
# 6         Anti-Monitor    Male    yellow  God / Eternal    No Hair  2.001312
# 86             Giganta  Female     green        unknown        Red  2.066929
# 118             Krypto    Male      blue     Kryptonian      White  2.099738
# 388    Howard the Duck    Male     brown        unknown     Yellow  2.591864
# 496     Rocket Raccoon    Male     brown         Animal      Brown  4.002625
# 173            Robin V    Male      blue          Human      Black  4.494751
# 591            Wiz Kid       -     brown        unknown      Black  4.593176
# 353  Franklin Richards    Male      blue         Mutant      Blond  4.658793
#
#          publisher alignment  weight          bmi
# 566  Marvel Comics       bad    58.0  2576.457960
# ...

# %%
#nsmallest & largest doesn't work with string

# %%
url  = "https://raw.githubusercontent.com/PacktPublishing/Python-for-Data-Analysis-step-by-step-with-projects-/main/games.csv"

# %%
s = pd.read_csv(url)

# %%
s.to_csv('games.csv')

# %%
url1 = "https://raw.githubusercontent.com/PacktPublishing/Python-for-Data-Analysis-step-by-step-with-projects-/main/teams.csv"

# %%
teams = pd.read_csv(url1)

# %%
teams.to_csv('teams.csv')
