# %%
# pandas.pivot_table:
#     create an excel style pivot table as a dataframe
#     agggregate diff statistics based on diff grps(index/row + column)

# %%
import pandas as pd
student = pd.read_csv('student.csv')

# %%
student.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         395 non-null    object
#  1   internet    395 non-null    object
#  2   studytime   395 non-null    object
#  3   familysize  395 non-null    object
#  4   age         395 non-null    int64
#  5   score       395 non-null    int64
# dtypes: int64(2), object(4)
# memory usage: 18.6+ KB

# %%
student
# Out:
#     sex internet        studytime familysize  age  score
# 0     F       no   2. 2 - 5 hours         >3   18      6
# 1     F      yes   2. 2 - 5 hours         >3   17      6
# 2     F      yes   2. 2 - 5 hours        <=3   15     10
# 3     F      yes  3. 5 - 10 hours         >3   15     15
# 4     F       no   2. 2 - 5 hours         >3   16     10
# ..   ..      ...              ...        ...  ...    ...
# 390   M       no   2. 2 - 5 hours        <=3   20      9
# 391   M      yes      1. <2 hours        <=3   17     16
# 392   M       no      1. <2 hours         >3   21      7
# 393   M      yes      1. <2 hours        <=3   18     10
# 394   M      yes      1. <2 hours        <=3   19      9
#
# [395 rows x 6 columns]

# %%
pd.pivot_table(student,index = 'sex') # mean
# Out:
#            age      score
# sex
# F    16.730769   9.966346
# M    16.657754  10.914439

# %%
pd.pivot_table(student,index = ['sex','internet'])
# Out:
#                     age      score
# sex internet
# F   no        17.078947   9.184211
#     yes       16.652941  10.141176
# M   no        16.928571   9.714286
#     yes       16.610063  11.125786

# %%
pd.pivot_table(student,index = ['sex','internet'],values = 'score')
# Out:
#                   score
# sex internet
# F   no         9.184211
#     yes       10.141176
# M   no         9.714286
#     yes       11.125786

# %%
pd.pivot_table(student,index = ['sex','internet'],values = 'score',aggfunc = ['min','median','max'])
# Out:
#                min median   max
#              score  score score
# sex internet
# F   no           0     10    18
#     yes          0     11    19
# M   no           0     11    18
#     yes          0     11    20

# %%
pd.pivot_table(student,index = ['sex','internet'],values = 'score',columns = 'studytime')
# Out:
# studytime     1. <2 hours  2. 2 - 5 hours  3. 5 - 10 hours  4. >10 hours
# sex internet
# F   no           9.857143        8.909091         8.600000     10.250000
#     yes          9.850000        9.637363        10.956522     11.230769
# M   no           9.666667        9.600000        12.000000           NaN
#     yes         10.196970       11.385714        14.000000     11.700000

# %%
pd.pivot_table(student,index = ['sex','internet'],values = 'score',columns = 'studytime',fill_value = -999)
# Out:
# studytime     1. <2 hours  2. 2 - 5 hours  3. 5 - 10 hours  4. >10 hours
# sex internet
# F   no           9.857143        8.909091         8.600000     10.250000
#     yes          9.850000        9.637363        10.956522     11.230769
# M   no           9.666667        9.600000        12.000000   -999.000000
#     yes         10.196970       11.385714        14.000000     11.700000

# %%
pd.pivot_table(student,index = ['sex','internet'],values = ['score','age'],columns = 'studytime',fill_value = -999)
# Out:
#                      age                                              \
# studytime    1. <2 hours 2. 2 - 5 hours 3. 5 - 10 hours 4. >10 hours
# sex internet
# F   no         16.428571      17.181818       17.600000    17.000000
#     yes        16.200000      16.626374       16.891304    16.692308
# M   no         17.166667      16.666667       18.000000  -999.000000
#     yes        16.712121      16.657143       16.692308    15.500000
#
#                    score
# studytime    1. <2 hours 2. 2 - 5 hours 3. 5 - 10 hours 4. >10 hours
# sex internet
# F   no          9.857143       8.909091        8.600000    10.250000
#     yes         9.850000       9.637363       10.956522    11.230769
# M   no          9.666667       9.600000       12.000000  -999.000000
#     yes        10.196970      11.385714       14.000000    11.700000

# %%
pd.pivot_table(student,index = 'sex',values = ['score','age'],columns = ['studytime','internet'],fill_value = -999)
# Out:
#                   age                                                       \
# studytime 1. <2 hours            2. 2 - 5 hours            3. 5 - 10 hours
# internet           no        yes             no        yes              no
# sex
# F           16.428571  16.200000      17.181818  16.626374            17.6
# M           17.166667  16.712121      16.666667  16.657143            18.0
#
#                                                    score            \
# studytime            4. >10 hours            1. <2 hours
# internet         yes           no        yes          no       yes
# sex
# F          16.891304           17  16.692308    9.857143   9.85000
# M          16.692308         -999  15.500000    9.666667  10.19697
#
#                                                                              \
# studytime 2. 2 - 5 hours            3. 5 - 10 hours            4. >10 hours
# internet              no        yes              no        yes           no
# sex
# ...

# %%
pd.pivot_table(student, index = 'familysize', columns  = 'sex',values = 'score')
# Out:
# sex                 F          M
# familysize
# <=3         10.980769  11.016129
# >3           9.628205  10.864000

# %%
pd.pivot_table(student, index = 'familysize', columns  = 'sex',values = 'score',margins = True,margins_name = 'Avg score')
# Out:
# sex                 F          M  Avg score
# familysize
# <=3         10.980769  11.016129  11.000000
# >3           9.628205  10.864000  10.177936
# Avg score    9.966346  10.914439  10.415190

# %%
student[student['sex'] == 'F'].mean()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21940\1446791806.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   student[student['sex'] == 'F'].mean()
# age      16.730769
# score     9.966346
# dtype: float64

# %%
# aggfunc works same as agg

# %%
pd.pivot_table(student, 
               index = 'studytime',
               columns = 'sex',
               values = ['age','score'], 
               aggfunc = {'age':['max','min'],'score':'median'})
# Out:
#                 age              score
#                 max     min     median
# sex               F   M   F   M      F     M
# studytime
# 1. <2 hours      18  22  15  15   11.0  10.0
# 2. 2 - 5 hours   19  20  15  15   10.0  11.0
# 3. 5 - 10 hours  20  18  15  15   11.0  14.0
# 4. >10 hours     19  18  15  15   11.0  12.5

# %%
def rangef(s):
    return s.max()-s.min()

# %%
pd.pivot_table(student, 
               index = 'studytime',
               columns = 'sex',
               values = 'score',
               aggfunc = rangef)
# Out:
# sex               F   M
# studytime
# 1. <2 hours      18  19
# 2. 2 - 5 hours   18  19
# 3. 5 - 10 hours  19   9
# 4. >10 hours     18  20

# %%
pd.pivot_table(student, 
               index = 'studytime',
               columns = 'sex',
               values = 'score',
               aggfunc = lambda s:s.max()-s.min())
# Out:
# sex               F   M
# studytime
# 1. <2 hours      18  19
# 2. 2 - 5 hours   18  19
# 3. 5 - 10 hours  19   9
# 4. >10 hours     18  20

# %%
# summary:
# index: keys to grp by on the pivot table index/row
# columns: keys to grp by o the pivot table column
# values: column to aggregate
# aggfunc: functions to use for aggregation
# margins = True
# fill_value
